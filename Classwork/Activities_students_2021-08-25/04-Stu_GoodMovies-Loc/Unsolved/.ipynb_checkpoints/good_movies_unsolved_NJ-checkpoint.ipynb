# %%
import pandas as pd
import numpy as mp
import os

# %%
file = os.path.join("Resources", "movie_scores.csv")
df = pd.read_csv(file)
df.head(2)
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
#
#    Metacritic  Metacritic_User  IMDB  Fandango_Stars  Fandango_Ratingvalue  \
# 0          66              7.1   7.8             5.0                   4.5
# 1          67              7.5   7.1             5.0                   4.5
#
#    RT_norm  RT_user_norm  ...  IMDB_norm  RT_norm_round  RT_user_norm_round  \
# 0     3.70           4.3  ...       3.90            3.5                 4.5
# 1     4.25           4.0  ...       3.55            4.5                 4.0
#
#    Metacritic_norm_round  Metacritic_user_norm_round  IMDB_norm_round  \
# 0                    3.5                         3.5              4.0
# 1                    3.5                         4.0              3.5
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  Fandango_votes  \
# ...

# %%
df.dtypes
# Out:
# FILM                           object
# RottenTomatoes                  int64
# RottenTomatoes_User             int64
# Metacritic                      int64
# Metacritic_User               float64
# IMDB                          float64
# Fandango_Stars                float64
# Fandango_Ratingvalue          float64
# RT_norm                       float64
# RT_user_norm                  float64
# Metacritic_norm               float64
# Metacritic_user_nom           float64
# IMDB_norm                     float64
# RT_norm_round                 float64
# RT_user_norm_round            float64
# Metacritic_norm_round         float64
# Metacritic_user_norm_round    float64
# IMDB_norm_round               float64
# Metacritic_user_vote_count      int64
# IMDB_user_vote_count            int64
# Fandango_votes                  int64
# Fandango_Difference           float64
# dtype: object

# %%
df_imdb = df.loc[df["IMDB"]>=7, ["FILM", "IMDB", "IMDB_norm", "IMDB_norm_round", "IMDB_user_vote_count"]]

# %%
df_imdb
# Out:
#                                           FILM  IMDB  IMDB_norm  \
# 0               Avengers: Age of Ultron (2015)   7.8       3.90
# 1                            Cinderella (2015)   7.1       3.55
# 2                               Ant-Man (2015)   7.8       3.90
# 5                     The Water Diviner (2015)   7.2       3.60
# 8                 Shaun the Sheep Movie (2015)   7.4       3.70
# ..                                         ...   ...        ...
# 140                          Inside Out (2015)   8.6       4.30
# 141                          Mr. Holmes (2015)   7.4       3.70
# 142                                 '71 (2015)   7.2       3.60
# 143                 Two Days, One Night (2014)   7.4       3.70
# 144  Gett: The Trial of Viviane Amsalem (2015)   7.8       3.90
#
#      IMDB_norm_round  IMDB_user_vote_count
# 0                4.0                271107
# 1                3.5                 65709
# 2                4.0                103660
# ...

# %%
df_imdb_lesspopular = df.loc[(df["IMDB"]>=7) & (df["IMDB_user_vote_count"]<20000), ["FILM", "IMDB", "IMDB_norm", "IMDB_norm_round", "IMDB_user_vote_count"]]

# %%
df_imdb_lesspopular.head(-5)
# Out:
#                                                   FILM  IMDB  IMDB_norm  \
# 8                         Shaun the Sheep Movie (2015)   7.4       3.70
# 9                                  Love & Mercy (2015)   7.8       3.90
# 10                   Far From The Madding Crowd (2015)   7.2       3.60
# 20                               McFarland, USA (2015)   7.5       3.75
# 29                          The End of the Tour (2015)   7.9       3.95
# 30                                     Red Army (2015)   7.7       3.85
# 31                        When Marnie Was There (2015)   7.8       3.90
# 32                           The Hunting Ground (2015)   7.5       3.75
# 41                                     Timbuktu (2015)   7.2       3.60
# 43                  The Diary of a Teenage Girl (2015)   7.0       3.50
# 66                                     The Gift (2015)   7.6       3.80
# 68                               Monkey Kingdom (2015)   7.3       3.65
# ...
