# %%
# Dependencies
import requests
from pprint import pprint
from config import nyt_key

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
# https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=yourkey

# %%
# Search for articles that mention granola
query = "granola"

# %%
# Build query URL
#query_url = url + "api-key=" + nyt_key + "&q=" + query

query_url = url +"q="+ query + "&api-key=" + nyt_key

# %%
# Request articles
import json
response = requests.get(query_url).json()
response
#json.dumps(response, sort_keys=True, indent=4)

# The "response" property in articles contains the actual articles
# list comprehension
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'This simple recipe has a deep coconut-spice flavor and a light, crunchy and delightfully clumpy texture.',
#     'web_url': 'https://www.nytimes.com/2016/05/11/dining/granola-recipe-clusters-video.html',
#     'snippet': 'This simple recipe has a deep coconut-spice flavor and a light, crunchy and delightfully clumpy texture.',
#     'lead_paragraph': 'Ever since I started making it several years ago, I’ve been loyal to one granola recipe that I picked up from a Brooklyn company called Early Bird.',
#     'print_section': 'D',
#     'print_page': '2',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Granola That’s Packed With Clusters',
#      'kicker': 'A Good Appetite',
#      'content_kicker': None,
#      'print_headline': 'A Sticky Secret to Granola',
#      'name': None,
#      'seo': None,
# ...

# %%
# Print the web_url of each stored article
article_list= response["response"]["docs"]
article_list
#print({i["response"]["docs"][0]["web_url"] for i in response})
print("Your requested articles:")
({print(article["web_url"]) for article in article_list})
# Out:
# Your requested articles:
# https://www.nytimes.com/2016/05/11/dining/granola-recipe-clusters-video.html
# https://cooking.nytimes.com/recipes/1014040-granola
# https://cooking.nytimes.com/recipes/1014414-granola
# https://www.nytimes.com/video/dining/1194817105861/making-granola.html
# https://cooking.nytimes.com/recipes/1020980-strawberry-granola
# https://www.nytimes.com/1999/01/24/nyregion/they-stand-by-their-granola.html
# https://www.nytimes.com/2012/03/25/magazine/who-made-that-granola.html
# https://cooking.nytimes.com/recipes/1012921-granola-muffins
# https://www.nytimes.com/2000/11/22/living/granola.html
# https://www.nytimes.com/2010/09/22/dining/22mini.html
# {None}
