# %%
# Dependencies
import requests
from config import api_key

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
query = 'coronavirus'

# Search for articles published between a begin and end date
begin_date=20200101
end_date=20200130

# Build url
#query_url = f"{url}api-key={api_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
query_url = url + "api-key=" + api_key + "&q=" + query + "&begin_date=" + str(begin_date) + "&end_date" + str(end_date) 
#+ "begin_date=" + str(begin_date) + "&end_date" + str(end_date)
#query_url

# %%
# Retrieve articles
response = requests.get(query_url).json()
response
#import json
#json.dumps(response, indent=4)
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': 'The deaths, spread out across four states in January 2020, have become part of a scattershot collection of clues about the virus’s early spread.',
#     'web_url': 'https://www.nytimes.com/2021/09/09/health/first-covid-deaths.html',
#     'snippet': 'The deaths, spread out across four states in January 2020, have become part of a scattershot collection of clues about the virus’s early spread.',
#     'lead_paragraph': 'Late last year, the federal government’s chief statistician on death received word about a tantalizing discovery: Someone had died from Covid-19 in January 2020, a death certificate said, a revelation that would have sped up the timeline of the virus’s spread in the United States by several weeks.',
#     'print_section': 'A',
#     'print_page': '24',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
# ...

# %%
article_list = response["response"]["docs"]
#web_url = response["response"]["docs"][0]["web_url"]
#articles = list[{abstracts, web_url}]
#articles
article_list
# Out:
# [{'abstract': 'The deaths, spread out across four states in January 2020, have become part of a scattershot collection of clues about the virus’s early spread.',
#   'web_url': 'https://www.nytimes.com/2021/09/09/health/first-covid-deaths.html',
#   'snippet': 'The deaths, spread out across four states in January 2020, have become part of a scattershot collection of clues about the virus’s early spread.',
#   'lead_paragraph': 'Late last year, the federal government’s chief statistician on death received word about a tantalizing discovery: Someone had died from Covid-19 in January 2020, a death certificate said, a revelation that would have sped up the timeline of the virus’s spread in the United States by several weeks.',
#   'print_section': 'A',
#   'print_page': '24',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
# ...

# %%
({print(f'A snippet from the article: \n{article["snippet"]} \n -----') for article in article_list})
#({print(article["web_url"]) for article in article_list})
# Out:
# A snippet from the article:
# The deaths, spread out across four states in January 2020, have become part of a scattershot collection of clues about the virus’s early spread.
#  -----
# A snippet from the article:
# Turning 12 has taken on added significance this summer, as tweens line up for shots allowing them to see friends and play sports again.
#  -----
# A snippet from the article:
# Prescriptions for ivermectin have jumped to more than 88,000 per week, some pharmacists are reporting shortages and people are overdosing on forms of the drug meant for horses.
#  -----
# A snippet from the article:
# The Food and Drug Administration will evaluate the new data as the Biden administration pushes a booster shot strategy.
#  -----
# A snippet from the article:
# As children head back for an uncertain school year, Dr. Anthony Fauci joined Times journalists for a vital Q&A for parents, educators and students everywhere.
#  -----
# A snippet from the article:
# ...

# %%
# BONUS: How would we get 30 results?
# HINT: Look up the page query param
