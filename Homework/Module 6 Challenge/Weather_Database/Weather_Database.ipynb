# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Generate 2000 random latitudes and longitudes

# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list. (Unpack the Zip File)
coordinates = list(lat_lngs)

# %%
# Check the last entry in the list
coordinates[1999]
# Out:
# (-28.182981276442554, 110.1063591311476)

# %%
coordinates[1999][0]
# Out:
# -28.182981276442554

# %%
coordinates[1999][1]
# Out:
# 110.1063591311476

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
cities
# Out:
# ['khuzhir',
#  'ushuaia',
#  'shingu',
#  'biscarrosse',
#  'lebu',
#  'payo',
#  'rikitea',
#  'punta arenas',
#  'tasiilaq',
#  'qazvin',
#  'nogales',
#  'deputatskiy',
#  'hobart',
#  'emba',
#  'albany',
#  'chokurdakh',
#  'cherskiy',
#  'mataura',
#  'hilo',
#  'tuktoyaktuk',
#  'veinticinco de mayo',
#  'upernavik',
#  'port alfred',
#  'chaumont',
#  'tabas',
#  'nikolskoye',
#  'chuy',
#  'atuona',
#  'aden',
#  'vaini',
#  'ancud',
#  'broome',
#  'sainte-anne-des-monts',
#  'severnyy-kospashskiy',
#  'guerrero negro',
#  'georgetown',
#  'puerto ayora',
#  'swan river',
#  'faanui',
#  'yar-sale',
#  'busselton',
#  'tateyama',
#  'hermanus',
#  'arlit',
#  'husavik',
#  'sonqor',
#  'sitka',
#  'fort nelson',
#  'grafton',
#  'foso',
#  'diffa',
#  'lompoc',
#  'jamestown',
#  'taolanaro',
#  'namatanai',
#  'margate',
#  'bluff',
#  'marivan',
#  'ciudad bolivar',
#  'phu ly',
#  'hualmay',
#  'neath',
#  'anchorage',
#  'leningradskiy',
#  'amderma',
#  'saldanha',
#  'aswan',
#  'namie',
#  'grand river south east',
#  'erzin',
#  'jaisalmer',
#  'umm lajj',
#  'dossor',
#  'east london',
#  'avarua',
#  'walvis bay',
#  'airai',
#  'victoria',
#  'katsuura',
#  'buala',
#  'tiruchchendur',
#  'saleaula',
#  'cape town',
#  'saint-philippe',
#  'dingle',
#  'port elizabeth',
#  'lae',
#  'port hedland',
#  'palabuhanratu',
#  'moche',
#  'schrobenhausen',
#  'carballo',
#  'jacqueville',
#  'augusto correa',
#  'lazaro cardenas',
#  'mogadishu',
#  'assiniboia',
#  'kyzyl-suu',
#  'sentyabrskiy',
#  'grindavik',
#  'clyde river',
#  'krasnyy chikoy',
#  'puyang',
#  'butaritari',
#  'kodiak',
#  'isangel',
#  'aviles',
#  'mys shmidta',
#  'illoqqortoormiut',
#  'cordoba',
#  'shubarkuduk',
#  'mount isa',
#  'port lincoln',
#  'victor harbor',
#  'nabire',
#  'kapaa',
#  'gold coast',
#  'selestat',
#  'grand gaube',
#  'labrea',
#  'barentsburg',
#  'antofagasta',
#  'lensk',
#  'san policarpo',
#  'nanortalik',
#  'surt',
#  'nizhneyansk',
#  'sofiysk',
#  'kuusamo',
#  'aksarayskiy',
#  'cerrito',
#  'yellowknife',
#  'ponta do sol',
#  'pacasmayo',
#  'mokrous',
#  'tiksi',
#  'edd',
#  'arraial do cabo',
#  'chichihualco',
#  'racale',
#  'abalak',
#  'san pedro',
#  'samusu',
#  'torbay',
#  'castro',
#  'marrakesh',
#  'xudat',
#  'tarko-sale',
#  'vanimo',
#  'codrington',
#  'mar del plata',
#  'gorontalo',
#  'manicaragua',
#  'vayalar',
#  'patratu',
#  'tiznit',
#  'leyland',
#  'belushya guba',
#  'lolua',
#  'bentiu',
#  'pevek',
#  'caceres',
#  'khani',
#  'cidreira',
#  'saint-michel-des-saints',
#  'ambalavao',
#  'barrow',
#  'general pico',
#  'hami',
#  'hemel hempstead',
#  'murray bridge',
#  'shchelyayur',
#  'nizhniy odes',
#  'hithadhoo',
#  'galveston',
#  'kimbe',
#  'nizhnevartovsk',
#  'kirakira',
#  'bathsheba',
#  'gidole',
#  'noumea',
#  'iquitos',
#  'saskylakh',
#  'klaksvik',
#  'fairbanks',
#  'puli',
#  'masterton',
#  'sheridan',
#  'new norfolk',
#  'maturin',
#  'seymchan',
#  'warrington',
#  'bambous virieux',
#  'moose factory',
#  'shache',
#  'tilichiki',
#  'toba',
#  'kuytun',
#  'druzhba',
#  'vodnyy',
#  'merrill',
#  'simpang',
#  'mandera',
#  'plettenberg bay',
#  'cabo san lucas',
#  'ust-kulom',
#  'naze',
#  'waipawa',
#  'kahului',
#  'kyren',
#  'kavaratti',
#  'suicheng',
#  'khatanga',
#  'baft',
#  'adrar',
#  'sagar',
#  'sorong',
#  'kamenskoye',
#  'balabac',
#  'sao filipe',
#  'sieradz',
#  'xuddur',
#  'umtata',
#  'vostok',
#  'sept-iles',
#  'esmeraldas',
#  'vydrino',
#  'tucumcari',
#  'attawapiskat',
#  'maniitsoq',
#  'nara',
#  'vardo',
#  'mirosov',
#  'kuyanovo',
#  'sabha',
#  'rocha',
#  'qui nhon',
#  'bredasdorp',
#  'quelimane',
#  'louisbourg',
#  'lorengau',
#  'balikpapan',
#  'kieta',
#  'narsaq',
#  'gotsu',
#  'kawalu',
#  'south yuba city',
#  'salalah',
#  'jalu',
#  'labutta',
#  'mahebourg',
#  'constitucion',
#  'lagoa',
#  'luderitz',
#  'bubaque',
#  'gimli',
#  'neya',
#  'provideniya',
#  'abu samrah',
#  'vung tau',
#  'ariogala',
#  'ugoofaaru',
#  'bur gabo',
#  'nizwa',
#  'port-gentil',
#  'hasaki',
#  'emerald',
#  'thompson',
#  'zyryanka',
#  'flinders',
#  'havoysund',
#  'kantilo',
#  'west wendover',
#  'kalmunai',
#  'aklavik',
#  'birjand',
#  'khandyga',
#  'kiunga',
#  'monrovia',
#  'sinkat',
#  'bend',
#  'chicama',
#  'sijunjung',
#  'mehran',
#  'albina',
#  'newport',
#  'iqaluit',
#  'vao',
#  'quang ngai',
#  'shepsi',
#  'muzhi',
#  'carnarvon',
#  'nampa',
#  'gambela',
#  'hanstholm',
#  'raga',
#  'grenada',
#  'lillooet',
#  'eyl',
#  'gambiran',
#  'meadow lake',
#  'oussouye',
#  'san quintin',
#  'warri',
#  'qurbah',
#  'tanete',
#  'lavrentiya',
#  'chagda',
#  'kaitangata',
#  'chulumani',
#  'klyuchi',
#  'talara',
#  'olafsvik',
#  'churachandpur',
#  'iskele',
#  'padang',
#  'bethel',
#  'ayan',
#  'jiuquan',
#  'bandrele',
#  'north bend',
#  'kangaba',
#  'saint anthony',
#  'san patricio',
#  'point fortin',
#  'kurskaya',
#  'muros',
#  'kuhestan',
#  'krasnovishersk',
#  'sola',
#  'komagane',
#  'ciudad real',
#  'buraydah',
#  'black river',
#  'dobeln',
#  'elk city',
#  'bahadurganj',
#  'qaanaaq',
#  'karratha',
#  'longyearbyen',
#  'batagay-alyta',
#  'sumoto',
#  'norman wells',
#  'tazovskiy',
#  'nuuk',
#  'vila franca do campo',
#  'charters towers',
#  'pochutla',
#  'roebourne',
#  'hearst',
#  'boone',
#  'yatou',
#  'dikson',
#  'katangli',
#  'kavieng',
#  'brae',
#  'petropavlovsk-kamchatskiy',
#  'centralia',
#  'hihya',
#  'omboue',
#  'ribeira grande',
#  'souillac',
#  'tigil',
#  'niquero',
#  'alta floresta',
#  'saint george',
#  'yenagoa',
#  'praia da vitoria',
#  'lasa',
#  'tura',
#  'boa vista',
#  'snezhnogorsk',
#  'rudnogorsk',
#  'pesqueria',
#  'nikolayevka',
#  'rivarolo canavese',
#  'collie',
#  'parry sound',
#  'marondera',
#  'homer',
#  'anadyr',
#  'ketchikan',
#  'igarka',
#  'shimoda',
#  'llanes',
#  'aksarka',
#  'geraldton',
#  'manaus',
#  'wichita falls',
#  'sedelnikovo',
#  'mozarlandia',
#  'kruisfontein',
#  'epe',
#  'coquimbo',
#  'caravelas',
#  'fare',
#  'saint-georges',
#  'himora',
#  'road town',
#  'mezen',
#  'xingtai',
#  'peniche',
#  'morant bay',
#  'whitianga',
#  'gizo',
#  'portland',
#  'skibotn',
#  'saint-pierre',
#  'porto velho',
#  'kochki',
#  'hongjiang',
#  'makubetsu',
#  'slavonice',
#  'dondo',
#  'bay city',
#  'chara',
#  'high prairie',
#  'sibolga',
#  'vrangel',
#  'vila velha',
#  'pisco',
#  'kinkala',
#  'kunming',
#  'alta gracia',
#  'atasu',
#  'dunedin',
#  'braniewo',
#  'tonantins',
#  'shenjiamen',
#  'pangnirtung',
#  'yeppoon',
#  'necochea',
#  'alofi',
#  'agadir',
#  'ulaangom',
#  'avera',
#  'turbat',
#  'hofn',
#  'shelbyville',
#  'narrabri',
#  'mineros',
#  'chumikan',
#  'pachino',
#  'myaundzha',
#  'wawa',
#  'cairns',
#  'port hardy',
#  'nishihara',
#  'gangotri',
#  'havelock',
#  'samalaeulu',
#  'touho',
#  'cabatuan',
#  'kholm',
#  'les cayes',
#  'male',
#  'henderson',
#  'la ronge',
#  'tuatapere',
#  'auki',
#  'bilibino',
#  'santa isabel',
#  'zyryanovsk',
#  'jiayuguan',
#  'san carlos de bariloche',
#  'adana',
#  'ucluelet',
#  'kargil',
#  'pangody',
#  'finspang',
#  'cap malheureux',
#  'pacific grove',
#  'sechura',
#  'cabedelo',
#  'leh',
#  'tongliao',
#  'curup',
#  'san jeronimo',
#  'arica',
#  'lata',
#  'nome',
#  'zhigansk',
#  'mehamn',
#  'kailua',
#  'pontes e lacerda',
#  'lima',
#  'davila',
#  'cedar city',
#  'invermere',
#  'severo-kurilsk',
#  'senador jose porfirio',
#  'beterou',
#  'montijo',
#  'salawagan',
#  'dodge city',
#  'kutum',
#  'porto torres',
#  'aragarcas',
#  'talnakh',
#  'conde',
#  'kaka',
#  'alice springs',
#  'esperance',
#  'sidi ali',
#  'barabai',
#  'malibu',
#  'zhoucun',
#  'djibo',
#  'tumannyy',
#  'acapulco',
#  'bengkulu',
#  'port moresby',
#  'namibe',
#  'ilulissat',
#  'thinadhoo',
#  'itaporanga',
#  'gamba',
#  'rognan',
#  'winton',
#  'elliot lake',
#  'lianzhou',
#  'richards bay',
#  'hobyo',
#  'nizamabad',
#  'oranjemund',
#  'ust-ilimsk',
#  'aktau',
#  'vaitupu',
#  'riviere-au-renard',
#  'kalabo',
#  'baykit',
#  'pahrump',
#  'darhan',
#  'lipari',
#  'umm kaddadah',
#  'dicabisagan',
#  'shahrud',
#  'svetlogorsk',
#  'rehoboth',
#  'marquette',
#  'xichang',
#  'fort-shevchenko',
#  'vestmannaeyjar',
#  'puqi',
#  'excelsior springs',
#  'nizhniy kuranakh',
#  'galesong',
#  'benguela',
#  'humaita',
#  'samarai',
#  'simao',
#  'carauari',
#  'malumfashi',
#  'sahrak',
#  'korhogo',
#  'nyagan',
#  'ruatoria',
#  'carahue',
#  'tambopata',
#  'demir kapija',
#  'poum',
#  'cockburn town',
#  'khromtau',
#  'guarapari',
#  'waterford',
#  'san fernando',
#  'savannah bight',
#  'billings',
#  'beringovskiy',
#  'kingaroy',
#  'broken hill',
#  'belawan',
#  'santa maria',
#  'los llanos de aridane',
#  'christchurch',
#  'manokwari',
#  'ibra',
#  'santa cruz',
#  'tsihombe',
#  'ayagoz',
#  'olinda',
#  'shakiso',
#  'uravakonda',
#  'bhadrak',
#  'manggar',
#  'nemuro',
#  'coffs harbour',
#  'praia',
#  'rincon',
#  'chifeng',
#  'ayutla',
#  'henties bay',
#  'hervey bay',
#  'blonduos',
#  'palu',
#  'yushu',
#  'netanya',
#  'kaiyuan',
#  'goderich',
#  'gainesville',
#  'mercedes',
#  'robertsport',
#  'doha',
#  'tuggurt',
#  'aljezur',
#  'gazli',
#  'westport',
#  'nelson',
#  'kijang',
#  'zaysan',
#  'san jose',
#  'kamaishi',
#  'bereda',
#  'sao joao da barra',
#  'baglung',
#  'daru',
#  'kumba',
#  'weihe',
#  'sorkjosen',
#  'majene',
#  'catalina foothills',
#  'marang',
#  'kearney',
#  'belmonte',
#  'boende',
#  'bairiki',
#  'lodwar',
#  'bayan',
#  'ahipara',
#  'ossora',
#  'tolaga bay',
#  'maryville',
#  'coihaique',
#  'honningsvag',
#  'te anau',
#  'cagayan de tawi-tawi',
#  'lewisburg',
#  'acari',
#  'bambanglipuro',
#  'sabang',
#  'ikalamavony',
#  'thunder bay',
#  'khekra',
#  'atar',
#  'tucurui',
#  'port blair',
#  'tikapur',
#  'kholodnyy',
#  'punta cardon',
#  'west fargo',
#  'chanika',
#  'moree',
#  'inhambane',
#  'griffith',
#  'yulara',
#  'navolato',
#  'mocambique',
#  'chapais',
#  'bolungarvik',
#  'anniston',
#  'flin flon',
#  'dalianwan',
#  'asau',
#  'ilave',
#  'birao',
#  'lhokseumawe',
#  'general bravo',
#  'tasbuget',
#  'linhares',
#  'japura',
#  'sindand',
#  'vallenar',
#  'diamantino',
#  'dujuma',
#  'saint-joseph',
#  'barawe',
#  'half moon bay',
#  'oktyabrskoye',
#  'valleyview',
#  'mbandaka',
#  'san cristobal',
#  'podor',
#  'linxia',
#  'smoky lake',
#  'nan',
#  'sanctorum',
#  'tomatlan',
#  'malanje',
#  'hay river',
#  'save',
#  'barra patuca',
#  'maymyo',
#  'sarkand',
#  'egvekinot',
#  'pabrade',
#  'lufilufi',
#  'grand-lahou',
#  'zhitikara',
#  'lexington',
#  'udachnyy',
#  'along',
#  'dokka',
#  'berlevag',
#  'san luis',
#  'wajima',
#  'borsele',
#  'trincomalee',
#  'adzope',
#  'namwala',
#  'yopal',
#  'huangchuan',
#  'urucara',
#  'shitanjing',
#  'sobolevo',
#  'urumqi',
#  'zhanakorgan',
#  'kathu',
#  'dakoro',
#  'kantang',
#  'yichun',
#  'skalat',
#  'kismayo',
#  'beipiao',
#  'utiroa',
#  'bundaberg',
#  'forbes',
#  'lodja',
#  'san andres',
#  'rojhan',
#  'djenne',
#  'raton',
#  'belokurikha',
#  'quatre cocos',
#  'kiama',
#  'plouzane',
#  'jacareacanga',
#  'kasempa',
#  'chimbote',
#  'hare bay',
#  'goedereede',
#  'khandbari',
#  'axim',
#  'tocopilla',
#  'waddan',
#  'ajdabiya',
#  'kazachinskoye',
#  'mantua',
#  'oxapampa',
#  'laplace',
#  'svobodnyy',
#  'ilmajoki',
#  'artyk',
#  'turukhansk',
#  'karpathos',
#  'nizhnyaya omka',
#  'tahe',
#  'acarau',
#  'halalo',
#  'punta de bombon',
#  'vibo valentia',
#  'ouesso',
#  'fernie',
#  'ustyuzhna',
#  'xinpu',
#  'kummersbruck',
#  'graulhet',
#  'bulembu']

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = round(city_weather["coord"]["lat"],2)
        city_lng = round(city_weather["coord"]["lon"],2)
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
#        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
#                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
#  OR     continue

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | khuzhir
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | shingu
# Processing Record 4 of Set 1 | biscarrosse
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | payo
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | qazvin
# Processing Record 11 of Set 1 | nogales
# Processing Record 12 of Set 1 | deputatskiy
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | emba
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | chokurdakh
# Processing Record 17 of Set 1 | cherskiy
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | veinticinco de mayo
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | port alfred
# Processing Record 24 of Set 1 | chaumont
# Processing Record 25 of Set 1 | tabas
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | chuy
# Processing Record 28 of Set 1 | atuona
# Processing Record 29 of Set 1 | aden
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | ancud
# Processing Record 32 of Set 1 | broome
# Processing Record 33 of Set 1 | sainte-anne-des-monts
# Processing Record 34 of Set 1 | severnyy-kospashskiy
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | swan river
# Processing Record 39 of Set 1 | faanui
# Processing Record 40 of Set 1 | yar-sale
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | tateyama
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | arlit
# Processing Record 45 of Set 1 | husavik
# Processing Record 46 of Set 1 | sonqor
# Processing Record 47 of Set 1 | sitka
# Processing Record 48 of Set 1 | fort nelson
# Processing Record 49 of Set 1 | grafton
# Processing Record 50 of Set 1 | foso
# Processing Record 1 of Set 2 | diffa
# Processing Record 2 of Set 2 | lompoc
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | namatanai
# Processing Record 6 of Set 2 | margate
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | marivan
# Processing Record 9 of Set 2 | ciudad bolivar
# Processing Record 10 of Set 2 | phu ly
# Processing Record 11 of Set 2 | hualmay
# Processing Record 12 of Set 2 | neath
# Processing Record 13 of Set 2 | anchorage
# Processing Record 14 of Set 2 | leningradskiy
# Processing Record 15 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | aswan
# Processing Record 18 of Set 2 | namie
# Processing Record 19 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 2 | erzin
# Processing Record 21 of Set 2 | jaisalmer
# Processing Record 22 of Set 2 | umm lajj
# Processing Record 23 of Set 2 | dossor
# Processing Record 24 of Set 2 | east london
# Processing Record 25 of Set 2 | avarua
# Processing Record 26 of Set 2 | walvis bay
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | katsuura
# Processing Record 30 of Set 2 | buala
# Processing Record 31 of Set 2 | tiruchchendur
# Processing Record 32 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | saint-philippe
# Processing Record 35 of Set 2 | dingle
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | lae
# Processing Record 38 of Set 2 | port hedland
# Processing Record 39 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 2 | moche
# Processing Record 41 of Set 2 | schrobenhausen
# Processing Record 42 of Set 2 | carballo
# Processing Record 43 of Set 2 | jacqueville
# Processing Record 44 of Set 2 | augusto correa
# Processing Record 45 of Set 2 | lazaro cardenas
# Processing Record 46 of Set 2 | mogadishu
# Processing Record 47 of Set 2 | assiniboia
# Processing Record 48 of Set 2 | kyzyl-suu
# Processing Record 49 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 2 | grindavik
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | krasnyy chikoy
# Processing Record 3 of Set 3 | puyang
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | isangel
# Processing Record 7 of Set 3 | aviles
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | cordoba
# Processing Record 11 of Set 3 | shubarkuduk
# Processing Record 12 of Set 3 | mount isa
# Processing Record 13 of Set 3 | port lincoln
# Processing Record 14 of Set 3 | victor harbor
# Processing Record 15 of Set 3 | nabire
# Processing Record 16 of Set 3 | kapaa
# Processing Record 17 of Set 3 | gold coast
# Processing Record 18 of Set 3 | selestat
# Processing Record 19 of Set 3 | grand gaube
# Processing Record 20 of Set 3 | labrea
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | antofagasta
# Processing Record 23 of Set 3 | lensk
# Processing Record 24 of Set 3 | san policarpo
# Processing Record 25 of Set 3 | nanortalik
# Processing Record 26 of Set 3 | surt
# Processing Record 27 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 3 | sofiysk
# City not found. Skipping...
# Processing Record 29 of Set 3 | kuusamo
# Processing Record 30 of Set 3 | aksarayskiy
# Processing Record 31 of Set 3 | cerrito
# Processing Record 32 of Set 3 | yellowknife
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | pacasmayo
# Processing Record 35 of Set 3 | mokrous
# Processing Record 36 of Set 3 | tiksi
# Processing Record 37 of Set 3 | edd
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | chichihualco
# Processing Record 40 of Set 3 | racale
# Processing Record 41 of Set 3 | abalak
# Processing Record 42 of Set 3 | san pedro
# Processing Record 43 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 3 | torbay
# Processing Record 45 of Set 3 | castro
# Processing Record 46 of Set 3 | marrakesh
# Processing Record 47 of Set 3 | xudat
# Processing Record 48 of Set 3 | tarko-sale
# Processing Record 49 of Set 3 | vanimo
# Processing Record 50 of Set 3 | codrington
# Processing Record 1 of Set 4 | mar del plata
# Processing Record 2 of Set 4 | gorontalo
# Processing Record 3 of Set 4 | manicaragua
# Processing Record 4 of Set 4 | vayalar
# Processing Record 5 of Set 4 | patratu
# City not found. Skipping...
# Processing Record 6 of Set 4 | tiznit
# Processing Record 7 of Set 4 | leyland
# Processing Record 8 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 4 | bentiu
# Processing Record 11 of Set 4 | pevek
# Processing Record 12 of Set 4 | caceres
# Processing Record 13 of Set 4 | khani
# Processing Record 14 of Set 4 | cidreira
# Processing Record 15 of Set 4 | saint-michel-des-saints
# Processing Record 16 of Set 4 | ambalavao
# Processing Record 17 of Set 4 | barrow
# Processing Record 18 of Set 4 | general pico
# Processing Record 19 of Set 4 | hami
# Processing Record 20 of Set 4 | hemel hempstead
# Processing Record 21 of Set 4 | murray bridge
# Processing Record 22 of Set 4 | shchelyayur
# City not found. Skipping...
# Processing Record 23 of Set 4 | nizhniy odes
# Processing Record 24 of Set 4 | hithadhoo
# Processing Record 25 of Set 4 | galveston
# Processing Record 26 of Set 4 | kimbe
# Processing Record 27 of Set 4 | nizhnevartovsk
# Processing Record 28 of Set 4 | kirakira
# Processing Record 29 of Set 4 | bathsheba
# Processing Record 30 of Set 4 | gidole
# Processing Record 31 of Set 4 | noumea
# Processing Record 32 of Set 4 | iquitos
# Processing Record 33 of Set 4 | saskylakh
# Processing Record 34 of Set 4 | klaksvik
# Processing Record 35 of Set 4 | fairbanks
# Processing Record 36 of Set 4 | puli
# Processing Record 37 of Set 4 | masterton
# Processing Record 38 of Set 4 | sheridan
# Processing Record 39 of Set 4 | new norfolk
# Processing Record 40 of Set 4 | maturin
# Processing Record 41 of Set 4 | seymchan
# Processing Record 42 of Set 4 | warrington
# Processing Record 43 of Set 4 | bambous virieux
# Processing Record 44 of Set 4 | moose factory
# Processing Record 45 of Set 4 | shache
# Processing Record 46 of Set 4 | tilichiki
# Processing Record 47 of Set 4 | toba
# Processing Record 48 of Set 4 | kuytun
# Processing Record 49 of Set 4 | druzhba
# Processing Record 50 of Set 4 | vodnyy
# Processing Record 1 of Set 5 | merrill
# Processing Record 2 of Set 5 | simpang
# Processing Record 3 of Set 5 | mandera
# Processing Record 4 of Set 5 | plettenberg bay
# Processing Record 5 of Set 5 | cabo san lucas
# Processing Record 6 of Set 5 | ust-kulom
# Processing Record 7 of Set 5 | naze
# Processing Record 8 of Set 5 | waipawa
# Processing Record 9 of Set 5 | kahului
# Processing Record 10 of Set 5 | kyren
# Processing Record 11 of Set 5 | kavaratti
# Processing Record 12 of Set 5 | suicheng
# Processing Record 13 of Set 5 | khatanga
# Processing Record 14 of Set 5 | baft
# Processing Record 15 of Set 5 | adrar
# Processing Record 16 of Set 5 | sagar
# Processing Record 17 of Set 5 | sorong
# Processing Record 18 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 5 | balabac
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | sieradz
# Processing Record 22 of Set 5 | xuddur
# Processing Record 23 of Set 5 | umtata
# Processing Record 24 of Set 5 | vostok
# Processing Record 25 of Set 5 | sept-iles
# Processing Record 26 of Set 5 | esmeraldas
# Processing Record 27 of Set 5 | vydrino
# Processing Record 28 of Set 5 | tucumcari
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | maniitsoq
# Processing Record 31 of Set 5 | nara
# Processing Record 32 of Set 5 | vardo
# Processing Record 33 of Set 5 | mirosov
# Processing Record 34 of Set 5 | kuyanovo
# Processing Record 35 of Set 5 | sabha
# Processing Record 36 of Set 5 | rocha
# Processing Record 37 of Set 5 | qui nhon
# Processing Record 38 of Set 5 | bredasdorp
# Processing Record 39 of Set 5 | quelimane
# Processing Record 40 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 5 | lorengau
# Processing Record 42 of Set 5 | balikpapan
# Processing Record 43 of Set 5 | kieta
# Processing Record 44 of Set 5 | narsaq
# Processing Record 45 of Set 5 | gotsu
# Processing Record 46 of Set 5 | kawalu
# Processing Record 47 of Set 5 | south yuba city
# Processing Record 48 of Set 5 | salalah
# Processing Record 49 of Set 5 | jalu
# Processing Record 50 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 6 | mahebourg
# Processing Record 2 of Set 6 | constitucion
# Processing Record 3 of Set 6 | lagoa
# Processing Record 4 of Set 6 | luderitz
# Processing Record 5 of Set 6 | bubaque
# Processing Record 6 of Set 6 | gimli
# Processing Record 7 of Set 6 | neya
# Processing Record 8 of Set 6 | provideniya
# Processing Record 9 of Set 6 | abu samrah
# Processing Record 10 of Set 6 | vung tau
# Processing Record 11 of Set 6 | ariogala
# Processing Record 12 of Set 6 | ugoofaaru
# Processing Record 13 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 6 | nizwa
# Processing Record 15 of Set 6 | port-gentil
# Processing Record 16 of Set 6 | hasaki
# Processing Record 17 of Set 6 | emerald
# Processing Record 18 of Set 6 | thompson
# Processing Record 19 of Set 6 | zyryanka
# Processing Record 20 of Set 6 | flinders
# Processing Record 21 of Set 6 | havoysund
# Processing Record 22 of Set 6 | kantilo
# Processing Record 23 of Set 6 | west wendover
# Processing Record 24 of Set 6 | kalmunai
# Processing Record 25 of Set 6 | aklavik
# Processing Record 26 of Set 6 | birjand
# Processing Record 27 of Set 6 | khandyga
# Processing Record 28 of Set 6 | kiunga
# Processing Record 29 of Set 6 | monrovia
# Processing Record 30 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 6 | bend
# Processing Record 32 of Set 6 | chicama
# Processing Record 33 of Set 6 | sijunjung
# Processing Record 34 of Set 6 | mehran
# Processing Record 35 of Set 6 | albina
# Processing Record 36 of Set 6 | newport
# Processing Record 37 of Set 6 | iqaluit
# Processing Record 38 of Set 6 | vao
# Processing Record 39 of Set 6 | quang ngai
# Processing Record 40 of Set 6 | shepsi
# Processing Record 41 of Set 6 | muzhi
# Processing Record 42 of Set 6 | carnarvon
# Processing Record 43 of Set 6 | nampa
# Processing Record 44 of Set 6 | gambela
# Processing Record 45 of Set 6 | hanstholm
# Processing Record 46 of Set 6 | raga
# Processing Record 47 of Set 6 | grenada
# Processing Record 48 of Set 6 | lillooet
# Processing Record 49 of Set 6 | eyl
# Processing Record 50 of Set 6 | gambiran
# Processing Record 1 of Set 7 | meadow lake
# Processing Record 2 of Set 7 | oussouye
# Processing Record 3 of Set 7 | san quintin
# Processing Record 4 of Set 7 | warri
# Processing Record 5 of Set 7 | qurbah
# City not found. Skipping...
# Processing Record 6 of Set 7 | tanete
# Processing Record 7 of Set 7 | lavrentiya
# Processing Record 8 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 7 | kaitangata
# Processing Record 10 of Set 7 | chulumani
# Processing Record 11 of Set 7 | klyuchi
# Processing Record 12 of Set 7 | talara
# Processing Record 13 of Set 7 | olafsvik
# Processing Record 14 of Set 7 | churachandpur
# Processing Record 15 of Set 7 | iskele
# Processing Record 16 of Set 7 | padang
# Processing Record 17 of Set 7 | bethel
# Processing Record 18 of Set 7 | ayan
# Processing Record 19 of Set 7 | jiuquan
# Processing Record 20 of Set 7 | bandrele
# Processing Record 21 of Set 7 | north bend
# Processing Record 22 of Set 7 | kangaba
# Processing Record 23 of Set 7 | saint anthony
# Processing Record 24 of Set 7 | san patricio
# Processing Record 25 of Set 7 | point fortin
# Processing Record 26 of Set 7 | kurskaya
# Processing Record 27 of Set 7 | muros
# Processing Record 28 of Set 7 | kuhestan
# City not found. Skipping...
# Processing Record 29 of Set 7 | krasnovishersk
# Processing Record 30 of Set 7 | sola
# Processing Record 31 of Set 7 | komagane
# Processing Record 32 of Set 7 | ciudad real
# Processing Record 33 of Set 7 | buraydah
# Processing Record 34 of Set 7 | black river
# Processing Record 35 of Set 7 | dobeln
# Processing Record 36 of Set 7 | elk city
# Processing Record 37 of Set 7 | bahadurganj
# Processing Record 38 of Set 7 | qaanaaq
# Processing Record 39 of Set 7 | karratha
# Processing Record 40 of Set 7 | longyearbyen
# Processing Record 41 of Set 7 | batagay-alyta
# Processing Record 42 of Set 7 | sumoto
# Processing Record 43 of Set 7 | norman wells
# Processing Record 44 of Set 7 | tazovskiy
# Processing Record 45 of Set 7 | nuuk
# Processing Record 46 of Set 7 | vila franca do campo
# Processing Record 47 of Set 7 | charters towers
# Processing Record 48 of Set 7 | pochutla
# Processing Record 49 of Set 7 | roebourne
# Processing Record 50 of Set 7 | hearst
# Processing Record 1 of Set 8 | boone
# Processing Record 2 of Set 8 | yatou
# Processing Record 3 of Set 8 | dikson
# Processing Record 4 of Set 8 | katangli
# Processing Record 5 of Set 8 | kavieng
# Processing Record 6 of Set 8 | brae
# Processing Record 7 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 8 | centralia
# Processing Record 9 of Set 8 | hihya
# Processing Record 10 of Set 8 | omboue
# Processing Record 11 of Set 8 | ribeira grande
# Processing Record 12 of Set 8 | souillac
# Processing Record 13 of Set 8 | tigil
# Processing Record 14 of Set 8 | niquero
# Processing Record 15 of Set 8 | alta floresta
# Processing Record 16 of Set 8 | saint george
# Processing Record 17 of Set 8 | yenagoa
# Processing Record 18 of Set 8 | praia da vitoria
# Processing Record 19 of Set 8 | lasa
# Processing Record 20 of Set 8 | tura
# Processing Record 21 of Set 8 | boa vista
# Processing Record 22 of Set 8 | snezhnogorsk
# Processing Record 23 of Set 8 | rudnogorsk
# Processing Record 24 of Set 8 | pesqueria
# Processing Record 25 of Set 8 | nikolayevka
# Processing Record 26 of Set 8 | rivarolo canavese
# Processing Record 27 of Set 8 | collie
# Processing Record 28 of Set 8 | parry sound
# Processing Record 29 of Set 8 | marondera
# Processing Record 30 of Set 8 | homer
# Processing Record 31 of Set 8 | anadyr
# Processing Record 32 of Set 8 | ketchikan
# Processing Record 33 of Set 8 | igarka
# Processing Record 34 of Set 8 | shimoda
# Processing Record 35 of Set 8 | llanes
# Processing Record 36 of Set 8 | aksarka
# Processing Record 37 of Set 8 | geraldton
# Processing Record 38 of Set 8 | manaus
# Processing Record 39 of Set 8 | wichita falls
# Processing Record 40 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 41 of Set 8 | mozarlandia
# Processing Record 42 of Set 8 | kruisfontein
# Processing Record 43 of Set 8 | epe
# Processing Record 44 of Set 8 | coquimbo
# Processing Record 45 of Set 8 | caravelas
# Processing Record 46 of Set 8 | fare
# Processing Record 47 of Set 8 | saint-georges
# Processing Record 48 of Set 8 | himora
# City not found. Skipping...
# Processing Record 49 of Set 8 | road town
# Processing Record 50 of Set 8 | mezen
# Processing Record 1 of Set 9 | xingtai
# Processing Record 2 of Set 9 | peniche
# Processing Record 3 of Set 9 | morant bay
# Processing Record 4 of Set 9 | whitianga
# Processing Record 5 of Set 9 | gizo
# Processing Record 6 of Set 9 | portland
# Processing Record 7 of Set 9 | skibotn
# Processing Record 8 of Set 9 | saint-pierre
# Processing Record 9 of Set 9 | porto velho
# Processing Record 10 of Set 9 | kochki
# Processing Record 11 of Set 9 | hongjiang
# Processing Record 12 of Set 9 | makubetsu
# Processing Record 13 of Set 9 | slavonice
# Processing Record 14 of Set 9 | dondo
# Processing Record 15 of Set 9 | bay city
# Processing Record 16 of Set 9 | chara
# Processing Record 17 of Set 9 | high prairie
# Processing Record 18 of Set 9 | sibolga
# Processing Record 19 of Set 9 | vrangel
# Processing Record 20 of Set 9 | vila velha
# Processing Record 21 of Set 9 | pisco
# Processing Record 22 of Set 9 | kinkala
# Processing Record 23 of Set 9 | kunming
# Processing Record 24 of Set 9 | alta gracia
# Processing Record 25 of Set 9 | atasu
# Processing Record 26 of Set 9 | dunedin
# Processing Record 27 of Set 9 | braniewo
# Processing Record 28 of Set 9 | tonantins
# Processing Record 29 of Set 9 | shenjiamen
# Processing Record 30 of Set 9 | pangnirtung
# Processing Record 31 of Set 9 | yeppoon
# Processing Record 32 of Set 9 | necochea
# Processing Record 33 of Set 9 | alofi
# Processing Record 34 of Set 9 | agadir
# Processing Record 35 of Set 9 | ulaangom
# Processing Record 36 of Set 9 | avera
# Processing Record 37 of Set 9 | turbat
# Processing Record 38 of Set 9 | hofn
# Processing Record 39 of Set 9 | shelbyville
# Processing Record 40 of Set 9 | narrabri
# Processing Record 41 of Set 9 | mineros
# Processing Record 42 of Set 9 | chumikan
# Processing Record 43 of Set 9 | pachino
# Processing Record 44 of Set 9 | myaundzha
# Processing Record 45 of Set 9 | wawa
# Processing Record 46 of Set 9 | cairns
# Processing Record 47 of Set 9 | port hardy
# Processing Record 48 of Set 9 | nishihara
# Processing Record 49 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 50 of Set 9 | havelock
# Processing Record 1 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 10 | touho
# Processing Record 3 of Set 10 | cabatuan
# Processing Record 4 of Set 10 | kholm
# Processing Record 5 of Set 10 | les cayes
# Processing Record 6 of Set 10 | male
# Processing Record 7 of Set 10 | henderson
# Processing Record 8 of Set 10 | la ronge
# Processing Record 9 of Set 10 | tuatapere
# Processing Record 10 of Set 10 | auki
# Processing Record 11 of Set 10 | bilibino
# Processing Record 12 of Set 10 | santa isabel
# Processing Record 13 of Set 10 | zyryanovsk
# Processing Record 14 of Set 10 | jiayuguan
# Processing Record 15 of Set 10 | san carlos de bariloche
# Processing Record 16 of Set 10 | adana
# Processing Record 17 of Set 10 | ucluelet
# Processing Record 18 of Set 10 | kargil
# Processing Record 19 of Set 10 | pangody
# Processing Record 20 of Set 10 | finspang
# Processing Record 21 of Set 10 | cap malheureux
# Processing Record 22 of Set 10 | pacific grove
# Processing Record 23 of Set 10 | sechura
# Processing Record 24 of Set 10 | cabedelo
# Processing Record 25 of Set 10 | leh
# Processing Record 26 of Set 10 | tongliao
# Processing Record 27 of Set 10 | curup
# Processing Record 28 of Set 10 | san jeronimo
# Processing Record 29 of Set 10 | arica
# Processing Record 30 of Set 10 | lata
# Processing Record 31 of Set 10 | nome
# Processing Record 32 of Set 10 | zhigansk
# Processing Record 33 of Set 10 | mehamn
# Processing Record 34 of Set 10 | kailua
# Processing Record 35 of Set 10 | pontes e lacerda
# Processing Record 36 of Set 10 | lima
# Processing Record 37 of Set 10 | davila
# Processing Record 38 of Set 10 | cedar city
# Processing Record 39 of Set 10 | invermere
# Processing Record 40 of Set 10 | severo-kurilsk
# Processing Record 41 of Set 10 | senador jose porfirio
# Processing Record 42 of Set 10 | beterou
# Processing Record 43 of Set 10 | montijo
# Processing Record 44 of Set 10 | salawagan
# Processing Record 45 of Set 10 | dodge city
# Processing Record 46 of Set 10 | kutum
# Processing Record 47 of Set 10 | porto torres
# Processing Record 48 of Set 10 | aragarcas
# Processing Record 49 of Set 10 | talnakh
# Processing Record 50 of Set 10 | conde
# Processing Record 1 of Set 11 | kaka
# Processing Record 2 of Set 11 | alice springs
# Processing Record 3 of Set 11 | esperance
# Processing Record 4 of Set 11 | sidi ali
# Processing Record 5 of Set 11 | barabai
# Processing Record 6 of Set 11 | malibu
# Processing Record 7 of Set 11 | zhoucun
# Processing Record 8 of Set 11 | djibo
# Processing Record 9 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 11 | acapulco
# Processing Record 11 of Set 11 | bengkulu
# Processing Record 12 of Set 11 | port moresby
# Processing Record 13 of Set 11 | namibe
# Processing Record 14 of Set 11 | ilulissat
# Processing Record 15 of Set 11 | thinadhoo
# Processing Record 16 of Set 11 | itaporanga
# Processing Record 17 of Set 11 | gamba
# Processing Record 18 of Set 11 | rognan
# Processing Record 19 of Set 11 | winton
# Processing Record 20 of Set 11 | elliot lake
# Processing Record 21 of Set 11 | lianzhou
# Processing Record 22 of Set 11 | richards bay
# Processing Record 23 of Set 11 | hobyo
# Processing Record 24 of Set 11 | nizamabad
# Processing Record 25 of Set 11 | oranjemund
# Processing Record 26 of Set 11 | ust-ilimsk
# Processing Record 27 of Set 11 | aktau
# Processing Record 28 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 11 | riviere-au-renard
# Processing Record 30 of Set 11 | kalabo
# Processing Record 31 of Set 11 | baykit
# Processing Record 32 of Set 11 | pahrump
# Processing Record 33 of Set 11 | darhan
# Processing Record 34 of Set 11 | lipari
# Processing Record 35 of Set 11 | umm kaddadah
# Processing Record 36 of Set 11 | dicabisagan
# Processing Record 37 of Set 11 | shahrud
# Processing Record 38 of Set 11 | svetlogorsk
# Processing Record 39 of Set 11 | rehoboth
# Processing Record 40 of Set 11 | marquette
# Processing Record 41 of Set 11 | xichang
# Processing Record 42 of Set 11 | fort-shevchenko
# Processing Record 43 of Set 11 | vestmannaeyjar
# Processing Record 44 of Set 11 | puqi
# Processing Record 45 of Set 11 | excelsior springs
# Processing Record 46 of Set 11 | nizhniy kuranakh
# Processing Record 47 of Set 11 | galesong
# Processing Record 48 of Set 11 | benguela
# Processing Record 49 of Set 11 | humaita
# Processing Record 50 of Set 11 | samarai
# Processing Record 1 of Set 12 | simao
# Processing Record 2 of Set 12 | carauari
# Processing Record 3 of Set 12 | malumfashi
# Processing Record 4 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 5 of Set 12 | korhogo
# Processing Record 6 of Set 12 | nyagan
# Processing Record 7 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 12 | carahue
# Processing Record 9 of Set 12 | tambopata
# Processing Record 10 of Set 12 | demir kapija
# Processing Record 11 of Set 12 | poum
# Processing Record 12 of Set 12 | cockburn town
# Processing Record 13 of Set 12 | khromtau
# Processing Record 14 of Set 12 | guarapari
# Processing Record 15 of Set 12 | waterford
# Processing Record 16 of Set 12 | san fernando
# Processing Record 17 of Set 12 | savannah bight
# Processing Record 18 of Set 12 | billings
# Processing Record 19 of Set 12 | beringovskiy
# Processing Record 20 of Set 12 | kingaroy
# Processing Record 21 of Set 12 | broken hill
# Processing Record 22 of Set 12 | belawan
# Processing Record 23 of Set 12 | santa maria
# Processing Record 24 of Set 12 | los llanos de aridane
# Processing Record 25 of Set 12 | christchurch
# Processing Record 26 of Set 12 | manokwari
# Processing Record 27 of Set 12 | ibra
# Processing Record 28 of Set 12 | santa cruz
# Processing Record 29 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 12 | ayagoz
# Processing Record 31 of Set 12 | olinda
# Processing Record 32 of Set 12 | shakiso
# Processing Record 33 of Set 12 | uravakonda
# Processing Record 34 of Set 12 | bhadrak
# Processing Record 35 of Set 12 | manggar
# Processing Record 36 of Set 12 | nemuro
# Processing Record 37 of Set 12 | coffs harbour
# Processing Record 38 of Set 12 | praia
# Processing Record 39 of Set 12 | rincon
# Processing Record 40 of Set 12 | chifeng
# Processing Record 41 of Set 12 | ayutla
# Processing Record 42 of Set 12 | henties bay
# Processing Record 43 of Set 12 | hervey bay
# Processing Record 44 of Set 12 | blonduos
# City not found. Skipping...
# Processing Record 45 of Set 12 | palu
# Processing Record 46 of Set 12 | yushu
# Processing Record 47 of Set 12 | netanya
# Processing Record 48 of Set 12 | kaiyuan
# Processing Record 49 of Set 12 | goderich
# Processing Record 50 of Set 12 | gainesville
# Processing Record 1 of Set 13 | mercedes
# Processing Record 2 of Set 13 | robertsport
# Processing Record 3 of Set 13 | doha
# Processing Record 4 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 5 of Set 13 | aljezur
# Processing Record 6 of Set 13 | gazli
# Processing Record 7 of Set 13 | westport
# Processing Record 8 of Set 13 | nelson
# Processing Record 9 of Set 13 | kijang
# Processing Record 10 of Set 13 | zaysan
# Processing Record 11 of Set 13 | san jose
# Processing Record 12 of Set 13 | kamaishi
# Processing Record 13 of Set 13 | bereda
# Processing Record 14 of Set 13 | sao joao da barra
# Processing Record 15 of Set 13 | baglung
# Processing Record 16 of Set 13 | daru
# Processing Record 17 of Set 13 | kumba
# Processing Record 18 of Set 13 | weihe
# Processing Record 19 of Set 13 | sorkjosen
# Processing Record 20 of Set 13 | majene
# Processing Record 21 of Set 13 | catalina foothills
# Processing Record 22 of Set 13 | marang
# Processing Record 23 of Set 13 | kearney
# Processing Record 24 of Set 13 | belmonte
# Processing Record 25 of Set 13 | boende
# Processing Record 26 of Set 13 | bairiki
# Processing Record 27 of Set 13 | lodwar
# Processing Record 28 of Set 13 | bayan
# Processing Record 29 of Set 13 | ahipara
# Processing Record 30 of Set 13 | ossora
# Processing Record 31 of Set 13 | tolaga bay
# Processing Record 32 of Set 13 | maryville
# Processing Record 33 of Set 13 | coihaique
# Processing Record 34 of Set 13 | honningsvag
# Processing Record 35 of Set 13 | te anau
# Processing Record 36 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 37 of Set 13 | lewisburg
# Processing Record 38 of Set 13 | acari
# Processing Record 39 of Set 13 | bambanglipuro
# Processing Record 40 of Set 13 | sabang
# Processing Record 41 of Set 13 | ikalamavony
# Processing Record 42 of Set 13 | thunder bay
# Processing Record 43 of Set 13 | khekra
# Processing Record 44 of Set 13 | atar
# Processing Record 45 of Set 13 | tucurui
# Processing Record 46 of Set 13 | port blair
# Processing Record 47 of Set 13 | tikapur
# Processing Record 48 of Set 13 | kholodnyy
# Processing Record 49 of Set 13 | punta cardon
# Processing Record 50 of Set 13 | west fargo
# Processing Record 1 of Set 14 | chanika
# Processing Record 2 of Set 14 | moree
# Processing Record 3 of Set 14 | inhambane
# Processing Record 4 of Set 14 | griffith
# Processing Record 5 of Set 14 | yulara
# Processing Record 6 of Set 14 | navolato
# Processing Record 7 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 8 of Set 14 | chapais
# Processing Record 9 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 14 | anniston
# Processing Record 11 of Set 14 | flin flon
# Processing Record 12 of Set 14 | dalianwan
# Processing Record 13 of Set 14 | asau
# Processing Record 14 of Set 14 | ilave
# Processing Record 15 of Set 14 | birao
# Processing Record 16 of Set 14 | lhokseumawe
# Processing Record 17 of Set 14 | general bravo
# Processing Record 18 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 19 of Set 14 | linhares
# Processing Record 20 of Set 14 | japura
# Processing Record 21 of Set 14 | sindand
# City not found. Skipping...
# Processing Record 22 of Set 14 | vallenar
# Processing Record 23 of Set 14 | diamantino
# Processing Record 24 of Set 14 | dujuma
# City not found. Skipping...
# Processing Record 25 of Set 14 | saint-joseph
# Processing Record 26 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 14 | half moon bay
# Processing Record 28 of Set 14 | oktyabrskoye
# Processing Record 29 of Set 14 | valleyview
# Processing Record 30 of Set 14 | mbandaka
# Processing Record 31 of Set 14 | san cristobal
# Processing Record 32 of Set 14 | podor
# Processing Record 33 of Set 14 | linxia
# Processing Record 34 of Set 14 | smoky lake
# Processing Record 35 of Set 14 | nan
# Processing Record 36 of Set 14 | sanctorum
# Processing Record 37 of Set 14 | tomatlan
# Processing Record 38 of Set 14 | malanje
# Processing Record 39 of Set 14 | hay river
# Processing Record 40 of Set 14 | save
# Processing Record 41 of Set 14 | barra patuca
# Processing Record 42 of Set 14 | maymyo
# Processing Record 43 of Set 14 | sarkand
# Processing Record 44 of Set 14 | egvekinot
# Processing Record 45 of Set 14 | pabrade
# Processing Record 46 of Set 14 | lufilufi
# Processing Record 47 of Set 14 | grand-lahou
# Processing Record 48 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 49 of Set 14 | lexington
# Processing Record 50 of Set 14 | udachnyy
# Processing Record 1 of Set 15 | along
# Processing Record 2 of Set 15 | dokka
# Processing Record 3 of Set 15 | berlevag
# Processing Record 4 of Set 15 | san luis
# Processing Record 5 of Set 15 | wajima
# Processing Record 6 of Set 15 | borsele
# Processing Record 7 of Set 15 | trincomalee
# Processing Record 8 of Set 15 | adzope
# Processing Record 9 of Set 15 | namwala
# Processing Record 10 of Set 15 | yopal
# Processing Record 11 of Set 15 | huangchuan
# Processing Record 12 of Set 15 | urucara
# Processing Record 13 of Set 15 | shitanjing
# Processing Record 14 of Set 15 | sobolevo
# Processing Record 15 of Set 15 | urumqi
# Processing Record 16 of Set 15 | zhanakorgan
# Processing Record 17 of Set 15 | kathu
# Processing Record 18 of Set 15 | dakoro
# Processing Record 19 of Set 15 | kantang
# Processing Record 20 of Set 15 | yichun
# Processing Record 21 of Set 15 | skalat
# Processing Record 22 of Set 15 | kismayo
# Processing Record 23 of Set 15 | beipiao
# Processing Record 24 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 25 of Set 15 | bundaberg
# Processing Record 26 of Set 15 | forbes
# Processing Record 27 of Set 15 | lodja
# Processing Record 28 of Set 15 | san andres
# Processing Record 29 of Set 15 | rojhan
# Processing Record 30 of Set 15 | djenne
# Processing Record 31 of Set 15 | raton
# Processing Record 32 of Set 15 | belokurikha
# Processing Record 33 of Set 15 | quatre cocos
# Processing Record 34 of Set 15 | kiama
# Processing Record 35 of Set 15 | plouzane
# Processing Record 36 of Set 15 | jacareacanga
# Processing Record 37 of Set 15 | kasempa
# Processing Record 38 of Set 15 | chimbote
# Processing Record 39 of Set 15 | hare bay
# Processing Record 40 of Set 15 | goedereede
# Processing Record 41 of Set 15 | khandbari
# Processing Record 42 of Set 15 | axim
# Processing Record 43 of Set 15 | tocopilla
# Processing Record 44 of Set 15 | waddan
# Processing Record 45 of Set 15 | ajdabiya
# Processing Record 46 of Set 15 | kazachinskoye
# Processing Record 47 of Set 15 | mantua
# Processing Record 48 of Set 15 | oxapampa
# Processing Record 49 of Set 15 | laplace
# Processing Record 50 of Set 15 | svobodnyy
# Processing Record 1 of Set 16 | ilmajoki
# Processing Record 2 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 16 | turukhansk
# Processing Record 4 of Set 16 | karpathos
# Processing Record 5 of Set 16 | nizhnyaya omka
# Processing Record 6 of Set 16 | tahe
# Processing Record 7 of Set 16 | acarau
# Processing Record 8 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 16 | punta de bombon
# Processing Record 10 of Set 16 | vibo valentia
# Processing Record 11 of Set 16 | ouesso
# Processing Record 12 of Set 16 | fernie
# Processing Record 13 of Set 16 | ustyuzhna
# Processing Record 14 of Set 16 | xinpu
# Processing Record 15 of Set 16 | kummersbruck
# Processing Record 16 of Set 16 | graulhet
# Processing Record 17 of Set 16 | bulembu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 720

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khuzhir      RU  53.19  107.34     51.55        74          55
# 1      Ushuaia      AR -54.80  -68.30     38.86        41          75
# 2       Shingu      JP  33.73  135.98     77.92        89         100
# 3  Biscarrosse      FR  44.39   -1.17     76.32        60           0
# 4         Lebu      CL -37.62  -73.65     54.23        67           1
#
#    Wind Speed Current Description
# 0        3.27       broken clouds
# 1        4.61       broken clouds
# 2        6.53     overcast clouds
# 3       13.80           clear sky
# 4        9.51           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
